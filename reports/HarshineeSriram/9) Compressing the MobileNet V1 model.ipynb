# %%
import numpy as np
import os
import keras
import tempfile
import tensorflow as tf
from tensorflow.keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.mobilenet import preprocess_input
from tensorflow_model_optimization.sparsity import keras as sparsity

# %%
model = tf.keras.models.load_model('model_MobileNet.h5')

# %%
nsfw_images = [fn for fn in os.listdir(r'D:\Data\Train\NSFW') if fn.endswith('.jpg')]
sfw_images = [fn for fn in os.listdir(r'D:\Data\Train\SFW') if fn.endswith('.jpg')]
train_dir = r'D:\Data\Train'
validation_dir = r'D:\Data\Validation'

def prepare_image(file):
    img_path = ''
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

train_datagen=ImageDataGenerator(preprocessing_function=preprocess_input) #included in our dependencies

train_generator=train_datagen.flow_from_directory(train_dir,
                                                 target_size=(224,224),
                                                 color_mode='rgb',
                                                 batch_size=30,
                                                 class_mode='categorical',
                                                 shuffle=True)

test_datagen = ImageDataGenerator( rescale = 1.0/255.)

validation_generator =test_datagen.flow_from_directory( validation_dir,
                                                          batch_size  = 30,
                                                          class_mode  = 'categorical', 
                                                          target_size = (224, 224))
# Out:
# Found 6394 images belonging to 2 classes.
# Found 2137 images belonging to 2 classes.

# %%
epochs = 10
end_step = np.ceil(1.0 * 6394 / 30).astype(np.int32) * epochs
print(end_step)
# Out:
# 2140

# %%
new_pruning_parameters = {
    'pruning_schedule': sparsity.PolynomialDecay(initial_sparsity=0.50,
                                                final_sparsity=0.90,
                                                begin_step=0,
                                                end_step=end_step,
                                                frequency=100)
}

new_pruned_model = sparsity.prune_low_magnitude(model, **new_pruning_parameters)
new_pruned_model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Harshinee Sriram\anaconda3\lib\site-packages\tensorflow_model_optimization\python\core\sparsity\keras\pruning_wrapper.py:215: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# prune_low_magnitude_conv1_pa (None, 225, 225, 3)       1
# _________________________________________________________________
# prune_low_magnitude_conv1 (P (None, 112, 112, 32)      1730
# _________________________________________________________________
# prune_low_magnitude_conv1_bn (None, 112, 112, 32)      129
# _________________________________________________________________
# prune_low_magnitude_conv1_re (None, 112, 112, 32)      1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 112, 112, 32)      289
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 112, 112, 32)      129
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 112, 112, 32)      1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 112, 112, 64)      4098
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 112, 112, 64)      257
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 112, 112, 64)      1
# _________________________________________________________________
# prune_low_magnitude_conv_pad (None, 113, 113, 64)      1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 56, 56, 64)        577
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 56, 56, 64)        257
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 56, 56, 64)        1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 56, 56, 128)       16386
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 56, 56, 128)       513
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 56, 56, 128)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 56, 56, 128)       1153
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 56, 56, 128)       513
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 56, 56, 128)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 56, 56, 128)       32770
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 56, 56, 128)       513
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 56, 56, 128)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pad (None, 57, 57, 128)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 28, 28, 128)       1153
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 28, 28, 128)       513
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 28, 28, 128)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 28, 28, 256)       65538
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 28, 28, 256)       1025
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 28, 28, 256)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 28, 28, 256)       2305
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 28, 28, 256)       1025
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 28, 28, 256)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 28, 28, 256)       131074
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 28, 28, 256)       1025
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 28, 28, 256)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pad (None, 29, 29, 256)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 256)       2305
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 256)       1025
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 256)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       262146
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       4609
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       524290
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       4609
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       524290
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       4609
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       524290
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       4609
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       524290
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       4609
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       524290
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       2049
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 14, 14, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_pad (None, 15, 15, 512)       1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 7, 7, 512)         4609
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 7, 7, 512)         2049
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 7, 7, 512)         1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 7, 7, 1024)        1048578
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 7, 7, 1024)        4097
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 7, 7, 1024)        1
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 7, 7, 1024)        9217
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 7, 7, 1024)        4097
# _________________________________________________________________
# prune_low_magnitude_conv_dw_ (None, 7, 7, 1024)        1
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 7, 7, 1024)        2097154
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 7, 7, 1024)        4097
# _________________________________________________________________
# prune_low_magnitude_conv_pw_ (None, 7, 7, 1024)        1
# _________________________________________________________________
# prune_low_magnitude_global_a (None, 1024)              1
# _________________________________________________________________
# prune_low_magnitude_dense (P (None, 1024)              2098178
# _________________________________________________________________
# prune_low_magnitude_dense_1  (None, 1024)              2098178
# _________________________________________________________________
# prune_low_magnitude_dense_2  (None, 512)               1049090
# _________________________________________________________________
# prune_low_magnitude_dense_3  (None, 2)                 2052
# =================================================================
# Total params: 11,616,911
# Trainable params: 5,817,986
# Non-trainable params: 5,798,925
# _________________________________________________________________

# %%
new_pruned_model.compile(
    loss = tf.keras.losses.categorical_crossentropy,
    optimizer='adam',
    metrics=['accuracy']
)

# %%
logdir = tempfile.mkdtemp()

callbacks = [
    sparsity.UpdatePruningStep(),
    sparsity.PruningSummaries(log_dir=logdir, profile_batch=0)
]

new_pruned_model.fit(train_generator, 
                    validation_data=validation_generator,
                    steps_per_epoch=int(6394/30),
                    validation_steps=int(2137/30),
                    epochs = epochs,
                    callbacks = callbacks)
# Out:
# Epoch 1/10
#   3/213 [..............................] - ETA: 8:08 - loss: 0.1576 - accuracy: 0.9556
# C:\Users\Harshinee Sriram\anaconda3\lib\site-packages\PIL\Image.py:2832: DecompressionBombWarning: Image size (147659204 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 213/213 [==============================] - 813s 4s/step - loss: 0.1905 - accuracy: 0.9365 - val_loss: 0.6549 - val_accuracy: 0.7906
# Epoch 2/10
# 213/213 [==============================] - 398s 2s/step - loss: 0.1139 - accuracy: 0.9613 - val_loss: 0.3153 - val_accuracy: 0.8915
# Epoch 3/10
# 213/213 [==============================] - 391s 2s/step - loss: 0.1099 - accuracy: 0.9624 - val_loss: 1.6244 - val_accuracy: 0.5934
# Epoch 4/10
# 213/213 [==============================] - 378s 2s/step - loss: 0.0945 - accuracy: 0.9665 - val_loss: 1.4174 - val_accuracy: 0.6376
# Epoch 5/10
# 213/213 [==============================] - 399s 2s/step - loss: 0.1210 - accuracy: 0.9554 - val_loss: 0.7994 - val_accuracy: 0.6512
# Epoch 6/10
# 213/213 [==============================] - 391s 2s/step - loss: 0.1059 - accuracy: 0.9620 - val_loss: 0.7637 - val_accuracy: 0.7028
# Epoch 7/10
# 213/213 [==============================] - 383s 2s/step - loss: 0.0876 - accuracy: 0.9661 - val_loss: 2.3271 - val_accuracy: 0.5371
# Epoch 8/10
# 213/213 [==============================] - 398s 2s/step - loss: 0.0742 - accuracy: 0.9725 - val_loss: 0.6640 - val_accuracy: 0.7254
# Epoch 9/10
# 213/213 [==============================] - 403s 2s/step - loss: 0.0533 - accuracy: 0.9830 - val_loss: 0.5034 - val_accuracy: 0.8042
# Epoch 10/10
# 213/213 [==============================] - 390s 2s/step - loss: 0.0389 - accuracy: 0.9865 - val_loss: 1.4161 - val_accuracy: 0.6831

# %%
final_model = sparsity.strip_pruning(new_pruned_model)
final_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 5,853,890
# Trainable params: 5,817,986
# Non-trainable params: 35,904
# _________________________________________________________________

# %%
final_model.save('compressed.h5')
model = load_model('compressed.h5')
for i, w in enumerate(model.get_weights()):
    print(
        "{} -- Total:{}, Zeros: {:.2f}%".format(
            model.weights[i].name, w.size, np.sum(w == 0) / w.size * 100
        )
    )
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# conv1/kernel:0 -- Total:864, Zeros: 90.05%
# conv1_bn/gamma:0 -- Total:32, Zeros: 0.00%
# conv1_bn/beta:0 -- Total:32, Zeros: 0.00%
# conv1_bn/moving_mean:0 -- Total:32, Zeros: 0.00%
# conv1_bn/moving_variance:0 -- Total:32, Zeros: 0.00%
# conv_dw_1/depthwise_kernel:0 -- Total:288, Zeros: 0.00%
# conv_dw_1_bn/gamma:0 -- Total:32, Zeros: 0.00%
# conv_dw_1_bn/beta:0 -- Total:32, Zeros: 0.00%
# conv_dw_1_bn/moving_mean:0 -- Total:32, Zeros: 0.00%
# conv_dw_1_bn/moving_variance:0 -- Total:32, Zeros: 0.00%
# conv_pw_1/kernel:0 -- Total:2048, Zeros: 89.99%
# conv_pw_1_bn/gamma:0 -- Total:64, Zeros: 0.00%
# conv_pw_1_bn/beta:0 -- Total:64, Zeros: 0.00%
# conv_pw_1_bn/moving_mean:0 -- Total:64, Zeros: 0.00%
# conv_pw_1_bn/moving_variance:0 -- Total:64, Zeros: 0.00%
# conv_dw_2/depthwise_kernel:0 -- Total:576, Zeros: 0.00%
# conv_dw_2_bn/gamma:0 -- Total:64, Zeros: 0.00%
# conv_dw_2_bn/beta:0 -- Total:64, Zeros: 0.00%
# conv_dw_2_bn/moving_mean:0 -- Total:64, Zeros: 0.00%
# conv_dw_2_bn/moving_variance:0 -- Total:64, Zeros: 0.00%
# conv_pw_2/kernel:0 -- Total:8192, Zeros: 90.00%
# conv_pw_2_bn/gamma:0 -- Total:128, Zeros: 0.00%
# conv_pw_2_bn/beta:0 -- Total:128, Zeros: 0.00%
# conv_pw_2_bn/moving_mean:0 -- Total:128, Zeros: 0.00%
# conv_pw_2_bn/moving_variance:0 -- Total:128, Zeros: 0.00%
# conv_dw_3/depthwise_kernel:0 -- Total:1152, Zeros: 0.00%
# conv_dw_3_bn/gamma:0 -- Total:128, Zeros: 0.00%
# conv_dw_3_bn/beta:0 -- Total:128, Zeros: 0.00%
# conv_dw_3_bn/moving_mean:0 -- Total:128, Zeros: 0.00%
# conv_dw_3_bn/moving_variance:0 -- Total:128, Zeros: 0.00%
# conv_pw_3/kernel:0 -- Total:16384, Zeros: 90.00%
# conv_pw_3_bn/gamma:0 -- Total:128, Zeros: 0.00%
# conv_pw_3_bn/beta:0 -- Total:128, Zeros: 0.00%
# conv_pw_3_bn/moving_mean:0 -- Total:128, Zeros: 0.00%
# conv_pw_3_bn/moving_variance:0 -- Total:128, Zeros: 0.00%
# conv_dw_4/depthwise_kernel:0 -- Total:1152, Zeros: 0.00%
# conv_dw_4_bn/gamma:0 -- Total:128, Zeros: 0.00%
# conv_dw_4_bn/beta:0 -- Total:128, Zeros: 0.00%
# conv_dw_4_bn/moving_mean:0 -- Total:128, Zeros: 0.78%
# conv_dw_4_bn/moving_variance:0 -- Total:128, Zeros: 0.78%
# conv_pw_4/kernel:0 -- Total:32768, Zeros: 90.00%
# conv_pw_4_bn/gamma:0 -- Total:256, Zeros: 0.00%
# conv_pw_4_bn/beta:0 -- Total:256, Zeros: 0.00%
# conv_pw_4_bn/moving_mean:0 -- Total:256, Zeros: 0.00%
# conv_pw_4_bn/moving_variance:0 -- Total:256, Zeros: 0.00%
# conv_dw_5/depthwise_kernel:0 -- Total:2304, Zeros: 0.00%
# conv_dw_5_bn/gamma:0 -- Total:256, Zeros: 0.00%
# conv_dw_5_bn/beta:0 -- Total:256, Zeros: 0.00%
# conv_dw_5_bn/moving_mean:0 -- Total:256, Zeros: 0.00%
# conv_dw_5_bn/moving_variance:0 -- Total:256, Zeros: 0.00%
# conv_pw_5/kernel:0 -- Total:65536, Zeros: 90.00%
# conv_pw_5_bn/gamma:0 -- Total:256, Zeros: 0.00%
# conv_pw_5_bn/beta:0 -- Total:256, Zeros: 0.00%
# conv_pw_5_bn/moving_mean:0 -- Total:256, Zeros: 0.00%
# conv_pw_5_bn/moving_variance:0 -- Total:256, Zeros: 0.00%
# conv_dw_6/depthwise_kernel:0 -- Total:2304, Zeros: 0.00%
# conv_dw_6_bn/gamma:0 -- Total:256, Zeros: 0.00%
# conv_dw_6_bn/beta:0 -- Total:256, Zeros: 0.00%
# conv_dw_6_bn/moving_mean:0 -- Total:256, Zeros: 0.00%
# conv_dw_6_bn/moving_variance:0 -- Total:256, Zeros: 0.00%
# conv_pw_6/kernel:0 -- Total:131072, Zeros: 90.00%
# conv_pw_6_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_pw_6_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_pw_6_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_pw_6_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_dw_7/depthwise_kernel:0 -- Total:4608, Zeros: 0.00%
# conv_dw_7_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_dw_7_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_dw_7_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_dw_7_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_pw_7/kernel:0 -- Total:262144, Zeros: 90.00%
# conv_pw_7_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_pw_7_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_pw_7_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_pw_7_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_dw_8/depthwise_kernel:0 -- Total:4608, Zeros: 0.00%
# conv_dw_8_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_dw_8_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_dw_8_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_dw_8_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_pw_8/kernel:0 -- Total:262144, Zeros: 90.00%
# conv_pw_8_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_pw_8_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_pw_8_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_pw_8_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_dw_9/depthwise_kernel:0 -- Total:4608, Zeros: 0.00%
# conv_dw_9_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_dw_9_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_dw_9_bn/moving_mean:0 -- Total:512, Zeros: 0.20%
# conv_dw_9_bn/moving_variance:0 -- Total:512, Zeros: 0.20%
# conv_pw_9/kernel:0 -- Total:262144, Zeros: 90.00%
# conv_pw_9_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_pw_9_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_pw_9_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_pw_9_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_dw_10/depthwise_kernel:0 -- Total:4608, Zeros: 0.00%
# conv_dw_10_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_dw_10_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_dw_10_bn/moving_mean:0 -- Total:512, Zeros: 0.20%
# conv_dw_10_bn/moving_variance:0 -- Total:512, Zeros: 0.20%
# conv_pw_10/kernel:0 -- Total:262144, Zeros: 90.00%
# conv_pw_10_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_pw_10_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_pw_10_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_pw_10_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_dw_11/depthwise_kernel:0 -- Total:4608, Zeros: 0.00%
# conv_dw_11_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_dw_11_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_dw_11_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_dw_11_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_pw_11/kernel:0 -- Total:262144, Zeros: 90.00%
# conv_pw_11_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_pw_11_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_pw_11_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_pw_11_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_dw_12/depthwise_kernel:0 -- Total:4608, Zeros: 0.00%
# conv_dw_12_bn/gamma:0 -- Total:512, Zeros: 0.00%
# conv_dw_12_bn/beta:0 -- Total:512, Zeros: 0.00%
# conv_dw_12_bn/moving_mean:0 -- Total:512, Zeros: 0.00%
# conv_dw_12_bn/moving_variance:0 -- Total:512, Zeros: 0.00%
# conv_pw_12/kernel:0 -- Total:524288, Zeros: 90.00%
# conv_pw_12_bn/gamma:0 -- Total:1024, Zeros: 0.00%
# conv_pw_12_bn/beta:0 -- Total:1024, Zeros: 0.00%
# conv_pw_12_bn/moving_mean:0 -- Total:1024, Zeros: 0.00%
# conv_pw_12_bn/moving_variance:0 -- Total:1024, Zeros: 0.00%
# conv_dw_13/depthwise_kernel:0 -- Total:9216, Zeros: 0.00%
# conv_dw_13_bn/gamma:0 -- Total:1024, Zeros: 0.00%
# conv_dw_13_bn/beta:0 -- Total:1024, Zeros: 0.00%
# conv_dw_13_bn/moving_mean:0 -- Total:1024, Zeros: 0.39%
# conv_dw_13_bn/moving_variance:0 -- Total:1024, Zeros: 0.39%
# conv_pw_13/kernel:0 -- Total:1048576, Zeros: 90.00%
# conv_pw_13_bn/gamma:0 -- Total:1024, Zeros: 0.00%
# conv_pw_13_bn/beta:0 -- Total:1024, Zeros: 0.00%
# conv_pw_13_bn/moving_mean:0 -- Total:1024, Zeros: 0.00%
# conv_pw_13_bn/moving_variance:0 -- Total:1024, Zeros: 0.00%
# dense/kernel:0 -- Total:1048576, Zeros: 90.00%
# dense/bias:0 -- Total:1024, Zeros: 0.00%
# dense_1/kernel:0 -- Total:1048576, Zeros: 90.00%
# dense_1/bias:0 -- Total:1024, Zeros: 0.00%
# dense_2/kernel:0 -- Total:524288, Zeros: 90.00%
# dense_2/bias:0 -- Total:512, Zeros: 0.00%
# dense_3/kernel:0 -- Total:1024, Zeros: 90.04%
# dense_3/bias:0 -- Total:2, Zeros: 0.00%
